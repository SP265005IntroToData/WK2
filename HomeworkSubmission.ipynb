# %% [markdown]
# ## What's the average rating for California wines ? ##
#
# scrapwork
#
# - isolate province for wine in csvdata(if (column2=US && column6=california))
# - californiaWine.append(csvdata)
# - californiaWineSum=0
# - for item in californiaWine (californiaWineSum + californiaWine[4 or 5? need check if start at 0])
# - need to convert price from string to int? ---> but when i print wine it's giving me int (34.0 etc)
# - californiaWineAvg= californiaWineSum / len(californiaWine)
#
# ### 44.15519877675841 ###

# %%
import csv
import math
csvfile=open("wines.csv")
csvreader=csv.reader(csvfile)
csvdata=list(csvreader)
californiaWines=[]
californiaWinePrices=[]

#print(csvdata[0])
#for loop isolated the columns bec it's for every row, print the values in column 1 and 5
# ALSO in python in the for loop they create a standalone (variable) (i think?) even if u dont define it b4hnd
#for wine in csvdata:
 # print(wine[1],wine[5])

for wine in csvdata[1:]:
  if (wine[1]=="US" and wine[5]=="California"):
    californiaWines.append(wine)
#print(californiaWines)


for wine in californiaWines:
  californiaWinePrices.append(float(wine[4]))
print(sum(californiaWinePrices))
#yay

caliWinePriceAvg = (sum(californiaWinePrices))/(len(californiaWinePrices))
print(caliWinePriceAvg)

#for price in californiaWinePrices:
  #float(price)
#print(californiaWinePrices)
#sum(californiaWinePrices)
# acc ran into a doozy here, i figured out that the values were stored as strings and realized that i needed to
# convert them to ints/floats but wasn't sure why it still wasnt working after this ^^^^: ended up asking chatgpt for help tbh
# and realized that it was cuz the floated values werent being stored in the list




#for wine in californiaWines:
  #print(wine[4])


#californiaWineSum= 0
#for wine in californiaWines:
  #californiaWineSum + wine[4]
#print (californiaWineSum)
# Out:
# [['0', 'US', "Martha's Vineyard", '96', '235.0', 'California', 'Napa Valley', 'Cabernet Sauvignon', 'Heitz'], ['2', 'US', 'Special Selected Late Harvest', '96', '90.0', 'California', 'Knights Valley', 'Sauvignon Blanc', 'Macauley'], ['9', 'US', "Gap's Crown Vineyard", '95', '60.0', 'California', 'Sonoma Coast', 'Pinot Noir', 'Blue Farm'], ['16', 'US', 'Rainin Vineyard', '95', '325.0', 'California', 'Diamond Mountain District', 'Cabernet Sauvignon', 'Hall'], ['19', 'US', "Gap's Crown Vineyard", '95', '75.0', 'California', 'Sonoma Coast', 'Pinot Noir', 'Gary Farrell'], ['20', 'US', 'Grignolino', '95', '24.0', 'California', 'Napa Valley', 'Rosé', 'Heitz'], ['23', 'US', 'Giallo Solare', '95', '60.0', 'California', 'Edna Valley', 'Chardonnay', 'Center of Effort'], ['24', 'US', 'R-Bar-R Ranch', '95', '45.0', 'California', 'Santa Cruz Mountains', 'Pinot Noir', 'Comartin'], ['28', 'US', "Garys' Vineyard", '94', '60.0', 'California', 'Santa Lucia Highlands', 'Pinot Noir', 'Roar'], ['31', 'US', 'Babushka', '90', '37.0', 'California', 'Russian River Valley', 'Chardonnay', 'Zepaltas'], ['47', 'US', 'Estate Grown', '90', '60.0', 'California', 'Mount Veeder', 'Cabernet Sauvignon', 'Brandlin'], ['65', 'US', 'Estate Select', '91', '36.0', 'California', 'Santa Clara Valley', 'Syrah', 'Jason-Stephens'], ['67', 'US', 'Animo', '91', '85.0', 'California', 'Napa Valley', 'Cabernet Sauvignon', 'Michael Mondavi Family Estate'], ['69', 'US', 'Barrel Select', '91', '60.0', 'California', 'Rutherford', 'Cabernet Sauvignon', 'Provenance Vineyards'], ['70', 'US', 'District Collection', '91', '85.0', 'California', 'St. Helena', 'Cabernet Sauvignon', 'Raymond'], ['77', 'US', 'Juliana Vineyard', '91', '38.0', 'California', 'Napa Valley', 'Sauvignon Blanc', 'B Cellars'], ['88', 'US', 'Bacigalupi Vineyard', '91', '65.0', 'California', 'Russian River Valley', 'Pinot Noir', 'Eleven Eleven'], ['89', 'US', 'Magnificat', '91', '50.0', 'California', 'Napa Valley', 'Meritage', 'Franciscan'], ['93', 'US', 'Small Lot Blend', '86', '13.0', 'California', 'Mendocino County', 'Chardonnay', 'Parducci'], ['101', 'US', 'Stephanie', '86', '50.0', 'California', 'Napa Valley', 'Cabernet Sauvignon', 'Hestan'], ['103', 'US', "Bella's Blend", '86', '48.0', 'California', 'Knights Valley', 'Cabernet Sauvignon-Cabernet Franc', 'Ehret'], ['104', 'US', 'Tears of Dew Late Harvest', '86', '20.0', 'California', 'Paso Robles', 'Moscato', 'EOS'], ['109', 'US', 'Homestead Block', '86', '45.0', 'California', 'Napa Valley', 'Chardonnay', 'Kuleto Estate'], ['112', 'US', 'Limited Release Cold Springs Vineyard', '86', '125.0', 'California', 'Howell Mountain', 'Cabernet Sauvignon', 'Charles Krug'], ['120', 'US', 'The Flyer', '91', '59.0', 'California', 'Russian River Valley', 'Pinot Noir', 'MacPhail'], ['121', 'US', 'Charles Vineyard Clone 05', '91', '49.0', 'California', 'Anderson Valley', 'Pinot Noir', 'Foursight'], ['122', 'US', 'Solomon Hills Vineyard Rosé', '91', '42.0', 'California', 'Santa Maria Valley', 'Sparkling Blend', 'Goat Bubbles'], ['123', 'US', 'Paris Tasting Commemorative', '91', '93.0', 'California', 'Napa Valley', 'Chardonnay', 'Grgich Hills'], ['124', 'US', "Methode a l'Ancienne", '91', '32.0', 'California', 'Anderson Valley', 'Pinot Noir', 'Navarro'], ['126', 'US', 'Grand Wren', '90', '100.0', 'California', 'Amador County', 'Zinfandel', 'Renwood'], ['127', 'US', 'Central Park West Vineyard', '90', '50.0', 'California', 'St. Helena', 'Cabernet Sauvignon', 'Trinchero'], ['132', 'US', 'Cooper Ranch', '90', '26.0', 'California', 'Amador County', 'Barbera', 'Andis'], ['134', 'US', 'Longwood', '90', '30.0', 'California', 'Napa Valley', 'Cabernet Sauvignon', 'Beaucanon'], ['135', 'US', 'Estate', '90', '42.0', 'California', 'Adelaida District', 'Grenache', 'Brecon Estate'], ['136', 'US', 'Mustang Springs', '90', '38.0', 'California', 'Adelaida District', 'Zinfandel', 'Peachy Canyon'], ['137', 'US', 'SMC', '90', '48.0', 'California', 'California', 'Rhône-style Red Blend', 'Three'], ['141 ...
# 115510.0
# 44.15519877675841

# %% [markdown]
# ## What's the most expensive wine from Spain ? ##

# %%
import csv
csvfile=open("wines.csv")
csvreader=csv.reader(csvfile)
csvdata=list(csvreader)
mostExpensive=0
spanishWine=[]
priciestSpanishWine=[]


#scrapwork
#print(csvdata[0])

#for wine in csvdata[1:]:
  #mostExpensive.append(float(wine[4]))
#print(mostExpensive)

#for wine in csvdata[1:] and test2:
  #if float(wine[4] in csvdata) > float(wine[4] in test2):
    #mostExpensive.append(wine)
#print(mostExpensive)

#initially wanted to complete this in 1 or 2 function, but trying to float and call individual rows from both lists proved a bit of
#a problem, changed it up to find the max price in general first, and then match the indiv lists

for wine in csvdata[1:]:
  if wine[1]=="Spain":
    spanishWine.append
  
for wine in spanishWine:
  if float(wine[4]) > mostExpensive:
    mostExpensive = float(wine[4])
print(mostExpensive)

for wine in csvdata[1:]:
  if wine[4]== mostExpensive:
    mostExpensiveWine = wine
print(mostExpensiveWine)
# Out:
# 2013.0
# ['13318', 'US', 'Roger Rose Vineyard', '91', '2013.0', 'California', 'Arroyo Seco', 'Chardonnay', 'Blair']

# %% [markdown]
# ## Where's the worse wine in the US from ? ##

# %% [markdown]
# ##  Which country between spain/us/france has highest average price ? ##

# %% [markdown]
# ## Which country between spain/us/france has highest average quality points ? ##

# %% [markdown]
# ##  Are the best wines also the most expensive ? ##
